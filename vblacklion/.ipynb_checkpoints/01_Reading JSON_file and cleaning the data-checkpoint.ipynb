# %%
# importing necessery modules
import pandas as pd
import json

# %%
# Since there are too many columns and we want to see all of them
from IPython.display import display
pd.options.display.max_columns=None

# %%
data = []
with open('../data/autos.json') as f:
    for line in f:
        data.append(json.loads(line))

# %%
df = pd.DataFrame(data)
df.head(3)
# Out:
#                            \nComfort & Convenience\n  \
# 0  [Air conditioning, Armrest, Automatic climate ...
# 1  [Air conditioning, Automatic climate control, ...
# 2  [Air conditioning, Armrest, Automatic climate ...
#
#                            \nEntertainment & Media\n  \
# 0  [Bluetooth, Hands-free equipment, On-board com...
# 1         [Bluetooth, MP3, On-board computer, Radio]
# 2  [Bluetooth, CD player, Hands-free equipment, O...
#
#                                  \nExtras\n  \
# 0                 [Alloy wheels, Roof rack]
# 1                            [Alloy wheels]
# 2  [Alloy wheels, Roof rack, Trailer hitch]
#
#                                \nSafety & Security\n Availability  \
# 0  [ABS, Central door lock, Daytime running light...          NaN
# 1  [ABS, Central door lock, Driver-side airbag, F...          NaN
# 2  [ABS, Alarm system, Central door lock, Daytime...          NaN
#
#   Available from                     Body       Body Color  \
# 0            NaN  [\n, Station wagon, \n]  [\n, Black, \n]
# 1            NaN  [\n, Station wagon, \n]  [\n, Black, \n]
# 2            NaN  [\n, Station wagon, \n]   [\n, Grey, \n]
#
#          Body Color Original               CO2 Emission  \
# 0      [\nBrillantschwarz\n]  [\n122 g CO2/km (comb)\n]
# 1                 [\nNero\n]                        NaN
# 2  [\nMonsungrau Metallic\n]  [\n125 g CO2/km (comb)\n]
#
#                        Consumption Country version Cylinders    Displacement  \
# 0  [[4.6 l/100 km (comb)], [], []]   [\nGermany\n]       NaN  [\n1,968 cc\n]
# 1                              NaN             NaN       NaN             NaN
# 2  [[4.7 l/100 km (comb)], [], []]   [\nGermany\n]       NaN  [\n1,968 cc\n]
#
#    Drive chain Electricity consumption Emission Class   Emission Label  \
# 0          NaN                     NaN   [\nEuro 6\n]              NaN
# 1          NaN                     NaN   [[], [], []]              NaN
# 2  [\nfront\n]                     NaN   [\nEuro 5\n]  [\n4 (Green)\n]
#
#   First Registration              Fuel          Full Service  \
# 0     [\n, 2015, \n]  [\n, Diesel, \n]  [\n, \n, \nEuro 6\n]
# 1     [\n, 2014, \n]  [\n, Diesel, \n]                   NaN
# 2     [\n, 2015, \n]  [\n, Diesel, \n]  [\n, \n, \nEuro 5\n]
#
#           Gearing Type    Gears Inspection new Last Service Date  \
# 0  [\n, Automatic, \n]      NaN            NaN               NaN
# 1  [\n, Automatic, \n]      NaN            NaN               NaN
# 2  [\n, Automatic, \n]  [\n8\n]            NaN               NaN
#
#   Last Timing Belt Service Date        Make         Model      Model Code  \
# 0                           NaN  [\nAudi\n]  [\n, A4, \n]             NaN
# 1                           NaN  [\nAudi\n]  [\n, A4, \n]             NaN
# 2                           NaN  [\nAudi\n]  [\n, A4, \n]  [\n0588/AXN\n]
#
#                           Next Inspection      Non-smoking Vehicle  \
# 0  [\n02/2020\n, \n122 g CO2/km (comb)\n]  [\n, \n, \n4 (Green)\n]
# 1                                     NaN                      NaN
# 2  [\n03/2020\n, \n125 g CO2/km (comb)\n]                      NaN
#
#   Nr. of Doors Nr. of Seats   Offer Number Other Fuel Types      Paint Type  \
# 0      [\n4\n]      [\n5\n]            NaN              NaN  [\nMetallic\n]
# 1      [\n5\n]      [\n5\n]  [\n2710463\n]              NaN  [\nMetallic\n]
# 2      [\n4\n]      [\n5\n]   [\n220418\n]              NaN  [\nMetallic\n]
#
#                                 Previous Owners  \
# 0  [\n1\n, \n, 4.6 l/100 km (comb), \n, \n, \n]
# 1                           [\n2\n, \nEuro 6\n]
# 2  [\n1\n, \n, 4.7 l/100 km (comb), \n, \n, \n]
#
#                              Type          Upholstery Warranty Weight  \
# 0  [\n, Used, \n, \n, Diesel, \n]  [\nCloth, Black\n]      NaN    NaN
# 1  [\n, Used, \n, \n, Diesel, \n]   [\nCloth, Grey\n]      NaN    NaN
# 2  [\n, Used, \n, \n, Diesel, \n]  [\nCloth, Black\n]      NaN    NaN
#
#        body_type                                        description        hp  \
# 0  Station wagon  [\n, Sonderausstattung:, Außenspiegel elektr. ...  [110 kW]
# 1  Station wagon  [\nDEK:[2710463], Per maggiori informazioni, a...  [110 kW]
# 2  Station wagon  [\nFahrzeugnummer: 220418, A4 Avant 2.0 TDI mu...  [110 kW]
#
#    kW            km    model null           price  \
# 0  []  [190,500 km]  Audi A4   []  \n€ 11,990.-\n
# 1  []  [164,533 km]  Audi A4   []  \n€ 12,200.-\n
# 2  []  [148,300 km]  Audi A4   []  \n€ 12,250.-\n
#
#                    registration               vat  \
# 0   [03/2015, 1 previous owner]                []
# 1  [11/2014, 2 previous owners]                []
# 2   [03/2015, 1 previous owner]  [VAT deductible]
#
#                                        version
# 0       Avant Ambient/I HAND/XENON/NAVI/S-Line
# 1        2.0 TDI CD 110kW multitronic Business
# 2  2.0 TDI Avant Multitr. Ambiente NAVI+ TEMPO

# %%
df.columns
# Out:
# Index(['\nComfort & Convenience\n', '\nEntertainment & Media\n', '\nExtras\n',
#        '\nSafety & Security\n', 'Availability', 'Available from', 'Body',
#        'Body Color', 'Body Color Original', 'CO2 Emission', 'Consumption',
#        'Country version', 'Cylinders', 'Displacement', 'Drive chain',
#        'Electricity consumption', 'Emission Class', 'Emission Label',
#        'First Registration', 'Fuel', 'Full Service', 'Gearing Type', 'Gears',
#        'Inspection new', 'Last Service Date', 'Last Timing Belt Service Date',
#        'Make', 'Model', 'Model Code', 'Next Inspection', 'Non-smoking Vehicle',
#        'Nr. of Doors', 'Nr. of Seats', 'Offer Number', 'Other Fuel Types',
#        'Paint Type', 'Previous Owners', 'Type', 'Upholstery', 'Warranty',
#        'Weight', 'body_type', 'description', 'hp', 'kW', 'km', 'model', 'null',
#        'price', 'registration', 'vat', 'version'],
#       dtype='object')

# %%
selected_columns = ['\nComfort & Convenience\n', '\nExtras\n', 'Drive chain', 'Electricity consumption',
                    'Emission Class', 'Emission Label', 'First Registration', 'Fuel', 'Nr. of Doors', 'Nr. of Seats',
                    'Offer Number', 'Other Fuel Types', 'Paint Type', 'Previous Owners', 'Type', 'Upholstery',
                    'Warranty', 'Weight']

# %%
len(selected_columns)
# Out:
# 18

# %%
df_v = df[selected_columns]
print(df_v.shape)
df_v.head(3)
# Out:
# (9558, 18)
#                            \nComfort & Convenience\n  \
# 0  [Air conditioning, Armrest, Automatic climate ...
# 1  [Air conditioning, Automatic climate control, ...
# 2  [Air conditioning, Armrest, Automatic climate ...
#
#                                  \nExtras\n  Drive chain  \
# 0                 [Alloy wheels, Roof rack]          NaN
# 1                            [Alloy wheels]          NaN
# 2  [Alloy wheels, Roof rack, Trailer hitch]  [\nfront\n]
#
#   Electricity consumption Emission Class   Emission Label First Registration  \
# 0                     NaN   [\nEuro 6\n]              NaN     [\n, 2015, \n]
# 1                     NaN   [[], [], []]              NaN     [\n, 2014, \n]
# 2                     NaN   [\nEuro 5\n]  [\n4 (Green)\n]     [\n, 2015, \n]
#
#                Fuel Nr. of Doors Nr. of Seats   Offer Number Other Fuel Types  \
# 0  [\n, Diesel, \n]      [\n4\n]      [\n5\n]            NaN              NaN
# 1  [\n, Diesel, \n]      [\n5\n]      [\n5\n]  [\n2710463\n]              NaN
# 2  [\n, Diesel, \n]      [\n4\n]      [\n5\n]   [\n220418\n]              NaN
#
#        Paint Type                               Previous Owners  \
# 0  [\nMetallic\n]  [\n1\n, \n, 4.6 l/100 km (comb), \n, \n, \n]
# 1  [\nMetallic\n]                           [\n2\n, \nEuro 6\n]
# 2  [\nMetallic\n]  [\n1\n, \n, 4.7 l/100 km (comb), \n, \n, \n]
#
#                              Type          Upholstery Warranty Weight
# 0  [\n, Used, \n, \n, Diesel, \n]  [\nCloth, Black\n]      NaN    NaN
# 1  [\n, Used, \n, \n, Diesel, \n]   [\nCloth, Grey\n]      NaN    NaN
# 2  [\n, Used, \n, \n, Diesel, \n]  [\nCloth, Black\n]      NaN    NaN

# %%
df_v[['Comfort&Convenience', 'Extras']] = df_v[['\nComfort & Convenience\n', '\nExtras\n']]
# Out:
# C:\Users\buono\Anaconda3\lib\site-packages\pandas\core\frame.py:3391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
df_v.columns
# Out:
# Index(['\nComfort & Convenience\n', '\nExtras\n', 'Drive chain',
#        'Electricity consumption', 'Emission Class', 'Emission Label',
#        'First Registration', 'Fuel', 'Nr. of Doors', 'Nr. of Seats',
#        'Offer Number', 'Other Fuel Types', 'Paint Type', 'Previous Owners',
#        'Type', 'Upholstery', 'Warranty', 'Weight', 'Comfort&Convenience',
#        'Extras'],
#       dtype='object')

# %%
df_v = df_v.drop(['\nComfort & Convenience\n', '\nExtras\n'], axis = 1 )
print(df_v.columns)
df_v.head(3)
# Out:
# Index(['Drive chain', 'Electricity consumption', 'Emission Class',
#        'Emission Label', 'First Registration', 'Fuel', 'Nr. of Doors',
#        'Nr. of Seats', 'Offer Number', 'Other Fuel Types', 'Paint Type',
#        'Previous Owners', 'Type', 'Upholstery', 'Warranty', 'Weight',
#        'Comfort&Convenience', 'Extras'],
#       dtype='object')
#    Drive chain Electricity consumption Emission Class   Emission Label  \
# 0          NaN                     NaN   [\nEuro 6\n]              NaN
# 1          NaN                     NaN   [[], [], []]              NaN
# 2  [\nfront\n]                     NaN   [\nEuro 5\n]  [\n4 (Green)\n]
#
#   First Registration              Fuel Nr. of Doors Nr. of Seats  \
# 0     [\n, 2015, \n]  [\n, Diesel, \n]      [\n4\n]      [\n5\n]
# 1     [\n, 2014, \n]  [\n, Diesel, \n]      [\n5\n]      [\n5\n]
# 2     [\n, 2015, \n]  [\n, Diesel, \n]      [\n4\n]      [\n5\n]
#
#     Offer Number Other Fuel Types      Paint Type  \
# 0            NaN              NaN  [\nMetallic\n]
# 1  [\n2710463\n]              NaN  [\nMetallic\n]
# 2   [\n220418\n]              NaN  [\nMetallic\n]
#
#                                 Previous Owners  \
# 0  [\n1\n, \n, 4.6 l/100 km (comb), \n, \n, \n]
# 1                           [\n2\n, \nEuro 6\n]
# 2  [\n1\n, \n, 4.7 l/100 km (comb), \n, \n, \n]
#
#                              Type          Upholstery Warranty Weight  \
# 0  [\n, Used, \n, \n, Diesel, \n]  [\nCloth, Black\n]      NaN    NaN
# 1  [\n, Used, \n, \n, Diesel, \n]   [\nCloth, Grey\n]      NaN    NaN
# 2  [\n, Used, \n, \n, Diesel, \n]  [\nCloth, Black\n]      NaN    NaN
#
#                                  Comfort&Convenience  \
# 0  [Air conditioning, Armrest, Automatic climate ...
# 1  [Air conditioning, Automatic climate control, ...
# 2  [Air conditioning, Armrest, Automatic climate ...
#
#                                      Extras
# 0                 [Alloy wheels, Roof rack]
# 1                            [Alloy wheels]
# 2  [Alloy wheels, Roof rack, Trailer hitch]

# %%
df_e.columns
# Out:
# Index(['Drive chain', 'Electricity consumption', 'Emission Class',
#        'Emission Label', 'First Registration', 'Fuel', 'Nr. of Doors',
#        'Nr. of Seats', 'Offer Number', 'Other Fuel Types', 'Paint Type',
#        'Previous Owners', 'Type', 'Upholstery', 'Warranty', 'Weight',
#        'Comfort&Convenience', 'Extras'],
#       dtype='object')
